# %%
import pandas as pd

# %%
df = pd.read_csv("../src/state/exp.csv", index_col=0)

# %%
df
# Out:
#          stopName                         stopDesc  zoneId zoneName   stopLat  \
# 45   Św. Wojciech                  Święty Wojciech     1.0   Gdańsk  54.28478
# 49     Olimpijska                       Olimpijska     1.0   Gdańsk  54.30558
# 23        Maćkowy                          Maćkowy     1.0   Gdańsk  54.30689
# 29     Przegalina                       Przegalina     1.0   Gdańsk  54.31122
# 48     Kampinoska                       Kampinoska     1.0   Gdańsk  54.31611
# ..            ...                              ...     ...      ...       ...
# 988           NaN                      Energetyków     NaN   Gdynia  54.53967
# 910           NaN            Chylonia Krzywoustego     NaN   Gdynia  54.54594
# 911           NaN             Bosmańska - Nasypowa     NaN   Gdynia  54.54853
# 912           NaN  Elektrociepłownia - Kontenerowa     NaN   Gdynia  54.55106
# 913           NaN            Cisowa Granica Miasta     NaN   Gdynia  54.55356
#
# ...

# %% [markdown]
# ## Legend

# %%
from branca.element import Template, MacroElement

template = """
{% macro html(this, kwargs) %}

<!doctype html>
<html lang="en">
<head>
  <meta charset="utf-8">
  <meta name="viewport" content="width=device-width, initial-scale=1">
  <title>jQuery UI Draggable - Default functionality</title>
  <link rel="stylesheet" href="//code.jquery.com/ui/1.12.1/themes/base/jquery-ui.css">

  <script src="https://code.jquery.com/jquery-1.12.4.js"></script>
  <script src="https://code.jquery.com/ui/1.12.1/jquery-ui.js"></script>
  
  <script>
  $( function() {
    $( "#maplegend" ).draggable({
                    start: function (event, ui) {
                        $(this).css({
                            right: "auto",
                            top: "auto",
                            bottom: "auto"
                        });
                    }
                });
});

  </script>
</head>
<body>

 
<div id='maplegend' class='maplegend' 
    style='position: absolute; z-index:9999; border:2px solid grey; background-color:rgba(255, 255, 255, 0.8);
     border-radius:6px; padding: 10px; font-size:14px; right: 20px; bottom: 20px;'>
     
<div class='legend-title'>Legend</div>
<div class='legend-scale'>
  <ul class='legend-labels'>
    <li><span style='background:green;opacity:0.7;'></span>t < 15 min</li>
    <li><span style='background:blue;opacity:0.7;'></span>15 min <= t < 30 min</li>
    <li><span style='background:yellow;opacity:0.7;'></span>30 min <= t < 45 min</li>
    <li><span style='background:red;opacity:0.7;'></span>45 min <= t < 60 min</li>
    <li><span style='background:black;opacity:0.7;'></span>60 min <= t</li>

  </ul>
</div>
</div>
 
</body>
</html>

<style type='text/css'>
  .maplegend .legend-title {
    text-align: left;
    margin-bottom: 5px;
    font-weight: bold;
    font-size: 90%;
    }
  .maplegend .legend-scale ul {
    margin: 0;
    margin-bottom: 5px;
    padding: 0;
    float: left;
    list-style: none;
    }
  .maplegend .legend-scale ul li {
    font-size: 80%;
    list-style: none;
    margin-left: 0;
    line-height: 18px;
    margin-bottom: 2px;
    }
  .maplegend ul.legend-labels li span {
    display: block;
    float: left;
    height: 16px;
    width: 30px;
    margin-right: 5px;
    margin-left: 0;
    border: 1px solid #999;
    }
  .maplegend .legend-source {
    font-size: 80%;
    color: #777;
    clear: both;
    }
  .maplegend a {
    color: #777;
    }
</style>
{% endmacro %}"""

# %% [markdown]
# ## Heatmap without time

# %%
from folium import plugins
from folium.plugins import HeatMap

map_3city = folium.Map(location=[54.441564, 18.562754], zoom_start = 10) 

df['Lat'] = df['stopLat'].astype(float)
df['Lon'] = df['stopLon'].astype(float)

heat_df = df[['Lat', 'Lon', 'color']]
heat_data = [[row['Lat'], row['Lon'], row['color']] for index, row in heat_df.iterrows()]

for index, row in heat_df.iterrows():
    folium.Circle(location=[row['Lat'], row['Lon']],
                  radius=150,
                  color=None,
                  fill=True,
                  fill_color=row['color'],
                  fill_opacity=1).add_to(map_3city)

macro = MacroElement()
macro._template = Template(template)

map_3city.get_root().add_child(macro)
    

map_3city.save("3city.html")
